# %% [markdown]
# <center>Group 6 Submission</center>

# %% [markdown]
# ### Reading the dataset & initial validations

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
dataSet = pd.read_csv('./UserRetentionData.csv')
dataSet
# Out:
#      Region  Tenure  Neighborhood Trunk Calling Facility Voice Messaging  \
# 0        KS     128           415                     No             Yes
# 1        OH     107           415                     No             Yes
# 2        NJ     137           415                     No              No
# 3        OH      84           408                    Yes              No
# 4        OK      75           415                    Yes              No
# ...     ...     ...           ...                    ...             ...
# 2661     SC      79           415                     No              No
# 2662     AZ     192           415                     No             Yes
# 2663     WV      68           415                     No              No
# 2664     RI      28           510                     No              No
# 2665     TN      74           415                     No             Yes
#
#       Number voice messages  Minutes Peak Hrs  Calls Peak Hrs  Bill Peak Hrs  \
# ...

# %%
dataSet.columns
# Out:
# Index(['Region', 'Tenure', 'Neighborhood', 'Trunk Calling Facility',
#        'Voice Messaging', 'Number voice messages', 'Minutes Peak Hrs',
#        'Calls Peak Hrs', 'Bill Peak Hrs', 'Minutes Off Peak', 'Calls Off Peak',
#        'Bill Off Peak', 'Minutes Night', 'Calls Night', 'Bill Night',
#        'Trunk Call Minutes', 'Trunk Calls', 'Trunk Call Bill',
#        'Contact for Grievances/Changes', 'Acct Closed?'],
#       dtype='object')

# %%
dataSet.info
# Out:
# <bound method DataFrame.info of      Region  Tenure  Neighborhood Trunk Calling Facility Voice Messaging  \
# 0        KS     128           415                     No             Yes
# 1        OH     107           415                     No             Yes
# 2        NJ     137           415                     No              No
# 3        OH      84           408                    Yes              No
# 4        OK      75           415                    Yes              No
# ...     ...     ...           ...                    ...             ...
# 2661     SC      79           415                     No              No
# 2662     AZ     192           415                     No             Yes
# 2663     WV      68           415                     No              No
# 2664     RI      28           510                     No              No
# 2665     TN      74           415                     No             Yes
#
# ...

# %%
dataSet.describe()
# Out:
#             Tenure  Neighborhood  Number voice messages  Minutes Peak Hrs  \
# count  2666.000000   2666.000000            2666.000000        2666.00000
# mean    100.620405    437.438860               8.021755         179.48162
# std      39.563974     42.521018              13.612277          54.21035
# min       1.000000    408.000000               0.000000           0.00000
# 25%      73.000000    408.000000               0.000000         143.40000
# 50%     100.000000    415.000000               0.000000         179.95000
# 75%     127.000000    510.000000              19.000000         215.90000
# max     243.000000    510.000000              50.000000         350.80000
#
#        Calls Peak Hrs  Bill Peak Hrs  Minutes Off Peak  Calls Off Peak  \
# count     2666.000000    2666.000000       2666.000000     2666.000000
# mean       100.310203      30.512404        200.386159      100.023631
# std         19.988162       9.215733         50.951515       20.161445
# ...

# %%
#checking if any feature has empty values in it
dataSet.isnull().sum()
# Out:
# Region                            0
# Tenure                            0
# Neighborhood                      0
# Trunk Calling Facility            0
# Voice Messaging                   0
# Number voice messages             0
# Minutes Peak Hrs                  0
# Calls Peak Hrs                    0
# Bill Peak Hrs                     0
# Minutes Off Peak                  0
# Calls Off Peak                    0
# Bill Off Peak                     0
# Minutes Night                     0
# Calls Night                       0
# Bill Night                        0
# Trunk Call Minutes                0
# Trunk Calls                       0
# Trunk Call Bill                   0
# Contact for Grievances/Changes    0
# Acct Closed?                      0
# dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
import numpy as np
from sklearn.metrics import roc_curve, auc

# %%
# dataSetOneHotEncoded = pd.get_dummies(dataSet, columns=['Trunk Calling Facility', 'Voice Messaging', ])
# X_encoded = pd.DataFrame(encoder.fit_transform(X), columns=encoder.get_feature_names_out(['categorical_feature']))

# applying label encoding to categorical values
# labelEncoder                        = LabelEncoder()
# backupDataSet                       = dataSet.copy()
# dataSet['Trunk Calling Facility']   = labelEncoder.fit_transform(dataSet['Trunk Calling Facility'])
# dataSet['Voice Messaging']          = labelEncoder.fit_transform(dataSet['Voice Messaging'])

labelencoder=LabelEncoder()

# %%
#encoding categorical variables
dataSet['Trunk Calling Facility']=labelencoder.fit_transform(dataSet['Trunk Calling Facility'])
dataSet['Voice Messaging']=labelencoder.fit_transform(dataSet['Voice Messaging'])
dataSet
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\user\OneDrive - Loyalist College\AI & DS\Sem 1\AISC1003 - ML\ML Grp 6 Activities\Assignment 3\machineLearning-Grp Assignment.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive%20-%20Loyalist%20College/AI%20%26%20DS/Sem%201/AISC1003%20-%20ML/ML%20Grp%206%20Activities/Assignment%203/machineLearning-Grp%20Assignment.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> #encoding categorical variables
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive%20-%20Loyalist%20College/AI%20%26%20DS/Sem%201/AISC1003%20-%20ML/ML%20Grp%206%20Activities/Assignment%203/machineLearning-Grp%20Assignment.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> dataSet['Trunk Calling Facility']=labelencoder.fit_transform(dataSet['Trunk Calling Facility'])
# ...
